# %%
import pandas as pd

df = pd.read_csv("emotions_train.csv")

unique_emotions = df["emotion"].unique()

print("Unique emotions:", unique_emotions)
# Out:
# Unique emotions: ['curiosity' 'anger' 'confusion' 'desire' 'gratitude' 'relief'
#  'excitement' 'optimism' 'nervousness' 'caring' 'embarrassment' 'pride'
#  'realization' 'disappointment' 'admiration' 'surprise' 'neutral'
#  'approval' 'disapproval' 'annoyance' 'amusement' 'sadness' 'remorse'
#  'fear' 'joy' 'grief' 'love']
